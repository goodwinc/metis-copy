# %% [markdown]
# # Basic SQL
#
#
# ### Learning Objectives
#
# * Overview of relational databases
# * Basic SQL
#     * Table and schema creation
#     * Loading data
#     * Selection syntax
#         * select
#         * where
#         * aggregations
#         * group by
#         * order by

# %% [markdown]
#
# ### Getting Started
#
# We will be using a pokemon dataset to play with the basics of SQL
#
# We will use pandas and SQLite as helper to make it easy to create our own databases. In most workplace conditions the database will be created for you, and you will need to get instructions from your DBA about the proper way to connect to your flavor of SQL database
#
# Usually you will need to have user credentials, a password, know the proper ip address and port, and install some drivers depending on the type of SQL.
#
# Just for a point of reference, see [here](https://dev.mysql.com/doc/connector-python/en/connector-python-example-connecting.html) on how you would use Python to connect to MySQL, one of the most popular SQL variants.

# %% [markdown]
# ![](https://img.pokemondb.net/artwork/bulbasaur.jpg)
#
# So to get started we will need to create a table:

# %%
import sqlite3 as sq3
import pandas.io.sql as pds
import pandas as pd

path = '../../sql_'
con = sq3.Connection(path + 'pokemon.db')


query = '''CREATE TABLE IF NOT EXISTS pokemon (
    id INTEGER NOT NULL, 
    name VARCHAR(30) NOT NULL,
    species_id INTEGER, 
    height INTEGER NOT NULL, 
    weight INTEGER NOT NULL, 
    base_experience INTEGER NOT NULL, 
    "order" INTEGER NOT NULL, 
    is_default INTEGER NOT NULL, 
    PRIMARY KEY (id), 
    CHECK (is_default IN (0, 1))
);'''

con.execute(query);

# %% [markdown]
# The following is how we get all data from a table.

# %%
query = '''SELECT * FROM pokemon;'''
pds.read_sql(query, con)
# Out:
# Empty DataFrame
# Columns: [id, name, species_id, height, weight, base_experience, order, is_default]
# Index: []

# %% [markdown]
# We can see that we create a table! but it's empty. We need a way to load data into it:

# %%
query = '''
INSERT INTO pokemon (id,name, species_id, height, weight, base_experience, "order", is_default) 
VALUES (0,'Missingno', 0, 1, 0.1, 100, 0, 0);
'''
con.execute(query)
con.commit()

# %% [markdown]
# Now if we look at the table:

# %%
query = '''SELECT * FROM pokemon;'''
pds.read_sql(query, con)
# Out:
#    id       name  species_id  height  weight  base_experience  order  \
# 0   0  Missingno           0       1     0.1              100      0
#
#    is_default
# 0           0

# %% [markdown]
# We can see we have some data. a Single Pokemon
#
# Really quick, lets try deleting that pokemon:

# %%
query = '''DELETE FROM pokemon where id=0;'''
con.execute(query)
con.commit()

# %% [markdown]
# And a Drop will get rid of that table all together:

# %%
query = '''DROP TABLE pokemon;'''
con.execute(query)
con.commit()

# %% [markdown]
# CREATE, INSERT, DELETE and DROP are useful to know, especially if you need to administer your own tables.
#
# However, there are some methods built into Pandas that make this process way more convienient.
#
# Let's try that now.

# %%
pokemon_df = pd.read_csv('data/pokemon_details.csv', index_col='id')
pokemon_df.to_sql('pokemon', con)

# %% [markdown]
# ## Select
# ![](https://img.pokemondb.net/artwork/pikachu.jpg)

# %%
query = '''SELECT * FROM pokemon limit 10;'''
pds.read_sql(query, con)
# Out:
#    id        name  height  weight  base_experience  type1   type2
# 0   1   bulbasaur       7      69               64  Grass  Poison
# 1   2     ivysaur      10     130              142  Grass  Poison
# 2   3    venusaur      20    1000              236  Grass  Poison
# 3   4  charmander       6      85               62   Fire    None
# 4   5  charmeleon      11     190              142   Fire    None
# 5   6   charizard      17     905              240   Fire  Flying
# 6   7    squirtle       5      90               63  Water    None
# 7   8   wartortle      10     225              142  Water    None
# 8   9   blastoise      16     855              239  Water    None
# 9  10    caterpie       3      29               39    Bug    None

# %%
query = '''SELECT name,height,weight FROM pokemon;'''
pds.read_sql(query, con)
# Out:
#            name  height  weight
# 0     bulbasaur       7      69
# 1       ivysaur      10     130
# 2      venusaur      20    1000
# 3    charmander       6      85
# 4    charmeleon      11     190
# 5     charizard      17     905
# 6      squirtle       5      90
# 7     wartortle      10     225
# 8     blastoise      16     855
# 9      caterpie       3      29
# 10      metapod       7      99
# 11   butterfree      11     320
# 12       weedle       3      32
# 13       kakuna       6     100
# 14     beedrill      10     295
# 15       pidgey       3      18
# 16    pidgeotto      11     300
# 17      pidgeot      15     395
# 18      rattata       3      35
# 19     raticate       7     185
# 20      spearow       3      20
# 21       fearow      12     380
# 22        ekans      20      69
# 23        arbok      35     650
# 24      pikachu       4      60
# 25       raichu       8     300
# 26    sandshrew       6     120
# 27    sandslash      10     295
# 28    nidoran-f       4      70
# 29     nidorina       8     200
# ..          ...     ...     ...
# 121     mr-mime      13     545
# 122     scyther      15     560
# 123        jynx      14     406
# 124  electabuzz      11     300
# 125      magmar      13     445
# 126      pinsir      15     550
# 127      tauros      14     884
# 128    magikarp       9     100
# 129    gyarados      65    2350
# 130      lapras      25    2200
# 131       ditto       3      40
# 132       eevee       3      65
# 133    vaporeon      10     290
# 134     jolteon       8     245
# 135     flareon       9     250
# 136     porygon       8     365
# 137     omanyte       4      75
# 138     omastar      10     350
# 139      kabuto       5     115
# 140    kabutops      13     405
# 141  aerodactyl      18     590
# 142     snorlax      21    4600
# 143    articuno      17     554
# 144      zapdos      16     526
# 145     moltres      20     600
# 146     dratini      18      33
# 147   dragonair      40     165
# 148   dragonite      22    2100
# 149      mewtwo      20    1220
# 150         mew       4      40
#
# [151 rows x 3 columns]

# %%
height_weight = pds.read_sql(query, con)
height_weight
# Out:
#            name  height  weight
# 0     bulbasaur       7      69
# 1       ivysaur      10     130
# 2      venusaur      20    1000
# 3    charmander       6      85
# 4    charmeleon      11     190
# 5     charizard      17     905
# 6      squirtle       5      90
# 7     wartortle      10     225
# 8     blastoise      16     855
# 9      caterpie       3      29
# 10      metapod       7      99
# 11   butterfree      11     320
# 12       weedle       3      32
# 13       kakuna       6     100
# 14     beedrill      10     295
# 15       pidgey       3      18
# 16    pidgeotto      11     300
# 17      pidgeot      15     395
# 18      rattata       3      35
# 19     raticate       7     185
# 20      spearow       3      20
# 21       fearow      12     380
# 22        ekans      20      69
# 23        arbok      35     650
# 24      pikachu       4      60
# 25       raichu       8     300
# 26    sandshrew       6     120
# 27    sandslash      10     295
# 28    nidoran-f       4      70
# 29     nidorina       8     200
# ..          ...     ...     ...
# 121     mr-mime      13     545
# 122     scyther      15     560
# 123        jynx      14     406
# 124  electabuzz      11     300
# 125      magmar      13     445
# 126      pinsir      15     550
# 127      tauros      14     884
# 128    magikarp       9     100
# 129    gyarados      65    2350
# 130      lapras      25    2200
# 131       ditto       3      40
# 132       eevee       3      65
# 133    vaporeon      10     290
# 134     jolteon       8     245
# 135     flareon       9     250
# 136     porygon       8     365
# 137     omanyte       4      75
# 138     omastar      10     350
# 139      kabuto       5     115
# 140    kabutops      13     405
# 141  aerodactyl      18     590
# 142     snorlax      21    4600
# 143    articuno      17     554
# 144      zapdos      16     526
# 145     moltres      20     600
# 146     dratini      18      33
# 147   dragonair      40     165
# 148   dragonite      22    2100
# 149      mewtwo      20    1220
# 150         mew       4      40
#
# [151 rows x 3 columns]

# %%
# %matplotlib inline
height_weight.plot.scatter('height','weight')

# %% [markdown]
# ### Exercise
#
# Select just the "name", "type1" and "type2" columns from the "pokemon" table.

# %%
# Your code here:
query = '''
SELECT name,type1,type2 FROM pokemon;
'''
pds.read_sql(query,con,index_col='name')
# Out:
#                type1    type2
# name
# bulbasaur      Grass   Poison
# ivysaur        Grass   Poison
# venusaur       Grass   Poison
# charmander      Fire     None
# charmeleon      Fire     None
# charizard       Fire   Flying
# squirtle       Water     None
# wartortle      Water     None
# blastoise      Water     None
# caterpie         Bug     None
# metapod          Bug     None
# butterfree       Bug   Flying
# weedle           Bug   Poison
# kakuna           Bug   Poison
# beedrill         Bug   Poison
# pidgey        Normal   Flying
# pidgeotto     Normal   Flying
# pidgeot       Normal   Flying
# rattata       Normal     None
# raticate      Normal     None
# spearow       Normal   Flying
# fearow        Normal   Flying
# ekans         Poison     None
# arbok         Poison     None
# pikachu     Electric     None
# raichu      Electric     None
# sandshrew     Ground     None
# sandslash     Ground     None
# nidoran-f     Poison     None
# nidorina      Poison     None
# ...              ...      ...
# mr-mime      Psychic    Fairy
# scyther          Bug   Flying
# jynx             Ice  Psychic
# electabuzz  Electric     None
# magmar          Fire     None
# pinsir           Bug     None
# tauros        Normal     None
# magikarp       Water     None
# gyarados       Water   Flying
# lapras         Water      Ice
# ditto         Normal     None
# eevee         Normal     None
# vaporeon       Water     None
# jolteon     Electric     None
# flareon         Fire     None
# porygon       Normal     None
# omanyte         Rock    Water
# omastar         Rock    Water
# kabuto          Rock    Water
# kabutops        Rock    Water
# aerodactyl      Rock   Flying
# snorlax       Normal     None
# articuno         Ice   Flying
# zapdos      Electric   Flying
# moltres         Fire   Flying
# dratini       Dragon     None
# dragonair     Dragon     None
# dragonite     Dragon   Flying
# mewtwo       Psychic     None
# mew          Psychic     None
#
# [151 rows x 2 columns]

# %% [markdown]
# ### Exercise
#
# What types of pokemon are there?

# %%
query = '''
SELECT distinct type1 as pokemon_type from pokemon
UNION
SELECT distinct type2 as pokemon_type from pokemon
'''
pds.read_sql(query,con)
# Out:
#    pokemon_type
# 0          None
# 1           Bug
# 2        Dragon
# 3      Electric
# 4         Fairy
# 5      Fighting
# 6          Fire
# 7        Flying
# 8         Ghost
# 9         Grass
# 10       Ground
# 11          Ice
# 12       Normal
# 13       Poison
# 14      Psychic
# 15         Rock
# 16        Steel
# 17        Water

# %%
query = '''
SELECT distinct type1
FROM pokemon'''
pds.read_sql(query, con)
# Out:
#        type1
# 0      Grass
# 1       Fire
# 2      Water
# 3        Bug
# 4     Normal
# 5     Poison
# 6   Electric
# 7     Ground
# 8      Fairy
# 9   Fighting
# 10   Psychic
# 11      Rock
# 12     Ghost
# 13       Ice
# 14    Dragon

# %% [markdown]
# ### Exercise
#
# How would you select all the distinct combinations of "type1" and "type2" present in the data? We haven't explicitly showed you how to do this, but take your best guess:

# %%
query = '''
SELECT distinct type1||COALESCE(type2,' ')
FROM pokemon'''
pds.read_sql(query, con)
# Out:
#    type1||COALESCE(type2,' ')
# 0                 GrassPoison
# 1                       Fire
# 2                  FireFlying
# 3                      Water
# 4                        Bug
# 5                   BugFlying
# 6                   BugPoison
# 7                NormalFlying
# 8                     Normal
# 9                     Poison
# 10                  Electric
# 11                    Ground
# 12               PoisonGround
# 13                     Fairy
# 14                NormalFairy
# 15               PoisonFlying
# 16                   BugGrass
# 17                  Fighting
# 18              WaterFighting
# 19                   Psychic
# 20                WaterPoison
# 21                 RockGround
# 22               WaterPsychic
# 23              ElectricSteel
# 24                   WaterIce
# 25                GhostPoison
# 26               GrassPsychic
# 27                 GroundRock
# 28                     Grass
# 29               PsychicFairy
# 30                 IcePsychic
# 31                WaterFlying
# 32                  RockWater
# 33                 RockFlying
# 34                  IceFlying
# 35             ElectricFlying
# 36                    Dragon
# 37               DragonFlying

# %% [markdown]
# ## Where
#
# ![](https://img.pokemondb.net/artwork/squirtle.jpg)

# %%
query = '''
SELECT name,height,weight,type1,type2 
FROM pokemon 
WHERE type1='Grass';'''
pds.read_sql(query, con)
# Out:
#           name  height  weight  type1    type2
# 0    bulbasaur       7      69  Grass   Poison
# 1      ivysaur      10     130  Grass   Poison
# 2     venusaur      20    1000  Grass   Poison
# 3       oddish       5      54  Grass   Poison
# 4        gloom       8      86  Grass   Poison
# 5    vileplume      12     186  Grass   Poison
# 6   bellsprout       7      40  Grass   Poison
# 7   weepinbell      10      64  Grass   Poison
# 8   victreebel      17     155  Grass   Poison
# 9    exeggcute       4      25  Grass  Psychic
# 10   exeggutor      20    1200  Grass  Psychic
# 11     tangela      10     350  Grass     None

# %% [markdown]
# ### Logic operators
#
# OR and AND can be used to combine multiple statements together

# %%
query = '''
SELECT name,height,weight,type1,type2 
FROM pokemon where type1='Grass' OR type2='Grass';'''
pds.read_sql(query, con)
# Out:
#           name  height  weight  type1    type2
# 0    bulbasaur       7      69  Grass   Poison
# 1      ivysaur      10     130  Grass   Poison
# 2     venusaur      20    1000  Grass   Poison
# 3       oddish       5      54  Grass   Poison
# 4        gloom       8      86  Grass   Poison
# 5    vileplume      12     186  Grass   Poison
# 6        paras       3      54    Bug    Grass
# 7     parasect      10     295    Bug    Grass
# 8   bellsprout       7      40  Grass   Poison
# 9   weepinbell      10      64  Grass   Poison
# 10  victreebel      17     155  Grass   Poison
# 11   exeggcute       4      25  Grass  Psychic
# 12   exeggutor      20    1200  Grass  Psychic
# 13     tangela      10     350  Grass     None

# %% [markdown]
# ### Exercise
#
# Select all the rows where "type1" is "grass" or "height" is greater than 10. Try to infer how you'd do this from the above example.

# %%
# Your code here
query = '''
SELECT *
FROM pokemon
WHERE type1 = 'grass'
OR height > 10
'''
pds.read_sql(query, con)
# Out:
#      id        name  height  weight  base_experience     type1     type2
# 0     3    venusaur      20    1000              236     Grass    Poison
# 1     5  charmeleon      11     190              142      Fire      None
# 2     6   charizard      17     905              240      Fire    Flying
# 3     9   blastoise      16     855              239     Water      None
# 4    12  butterfree      11     320              178       Bug    Flying
# 5    17   pidgeotto      11     300              122    Normal    Flying
# 6    18     pidgeot      15     395              216    Normal    Flying
# 7    22      fearow      12     380              155    Normal    Flying
# 8    23       ekans      20      69               58    Poison      None
# 9    24       arbok      35     650              153    Poison      None
# 10   31   nidoqueen      13     600              227    Poison    Ground
# 11   34    nidoking      14     620              227    Poison    Ground
# 12   36    clefable      13     400              217     Fairy      None
# 13   38   ninetales      11     199              177      Fire      None
# 14   42      golbat      16     550              159    Poison    Flying
# 15   45   vileplume      12     186              221     Grass    Poison
# 16   49    venomoth      15     125              158       Bug    Poison
# 17   55     golduck      17     766              175     Water      None
# 18   59    arcanine      19    1550              194      Fire      None
# 19   62   poliwrath      13     540              230     Water  Fighting
# 20   64     kadabra      13     565              140   Psychic      None
# 21   65    alakazam      15     480              225   Psychic      None
# 22   67     machoke      15     705              142  Fighting      None
# 23   68     machamp      16    1300              227  Fighting      None
# 24   71  victreebel      17     155              221     Grass    Poison
# 25   73  tentacruel      16     550              180     Water    Poison
# 26   76       golem      14    3000              223      Rock    Ground
# 27   78    rapidash      17     950              175      Fire      None
# 28   79    slowpoke      12     360               63     Water   Psychic
# 29   80     slowbro      16     785              172     Water   Psychic
# ..  ...         ...     ...     ...              ...       ...       ...
# 43  103   exeggutor      20    1200              182     Grass   Psychic
# 44  106   hitmonlee      15     498              159  Fighting      None
# 45  107  hitmonchan      14     502              159  Fighting      None
# 46  108   lickitung      12     655               77    Normal      None
# 47  110     weezing      12      95              172    Poison      None
# 48  112      rhydon      19    1200              170    Ground      Rock
# 49  113     chansey      11     346              395    Normal      None
# 50  115  kangaskhan      22     800              172    Normal      None
# 51  117      seadra      12     250              154     Water      None
# 52  119     seaking      13     390              158     Water      None
# 53  121     starmie      11     800              182     Water   Psychic
# 54  122     mr-mime      13     545              161   Psychic     Fairy
# 55  123     scyther      15     560              100       Bug    Flying
# 56  124        jynx      14     406              159       Ice   Psychic
# 57  125  electabuzz      11     300              172  Electric      None
# 58  126      magmar      13     445              173      Fire      None
# 59  127      pinsir      15     550              175       Bug      None
# 60  128      tauros      14     884              172    Normal      None
# 61  130    gyarados      65    2350              189     Water    Flying
# 62  131      lapras      25    2200              187     Water       Ice
# 63  141    kabutops      13     405              173      Rock     Water
# 64  142  aerodactyl      18     590              180      Rock    Flying
# 65  143     snorlax      21    4600              189    Normal      None
# 66  144    articuno      17     554              261       Ice    Flying
# 67  145      zapdos      16     526              261  Electric    Flying
# 68  146     moltres      20     600              261      Fire    Flying
# 69  147     dratini      18      33               60    Dragon      None
# 70  148   dragonair      40     165              147    Dragon      None
# 71  149   dragonite      22    2100              270    Dragon    Flying
# 72  150      mewtwo      20    1220              306   Psychic      None
#
# [73 rows x 7 columns]

# %%
query = '''
SELECT name,height,weight,type1,type2 
FROM pokemon where type1='Grass' AND type2='Poison';'''
pds.read_sql(query, con)
# Out:
#          name  height  weight  type1   type2
# 0   bulbasaur       7      69  Grass  Poison
# 1     ivysaur      10     130  Grass  Poison
# 2    venusaur      20    1000  Grass  Poison
# 3      oddish       5      54  Grass  Poison
# 4       gloom       8      86  Grass  Poison
# 5   vileplume      12     186  Grass  Poison
# 6  bellsprout       7      40  Grass  Poison
# 7  weepinbell      10      64  Grass  Poison
# 8  victreebel      17     155  Grass  Poison

# %% [markdown]
# Which Pokemon weigh over 1000units?

# %%
query = '''
SELECT * 
FROM pokemon 
WHERE weight > 1000;'''
pds.read_sql(query, con)
# Out:
#      id       name  height  weight  base_experience     type1    type2
# 0    59   arcanine      19    1550              194      Fire     None
# 1    68    machamp      16    1300              227  Fighting     None
# 2    75   graveler      10    1050              137      Rock   Ground
# 3    76      golem      14    3000              223      Rock   Ground
# 4    87    dewgong      17    1200              166     Water      Ice
# 5    91   cloyster      15    1325              184     Water      Ice
# 6    95       onix      88    2100               77      Rock   Ground
# 7   103  exeggutor      20    1200              182     Grass  Psychic
# 8   111    rhyhorn      10    1150               69    Ground     Rock
# 9   112     rhydon      19    1200              170    Ground     Rock
# 10  130   gyarados      65    2350              189     Water   Flying
# 11  131     lapras      25    2200              187     Water      Ice
# 12  143    snorlax      21    4600              189    Normal     None
# 13  149  dragonite      22    2100              270    Dragon   Flying
# 14  150     mewtwo      20    1220              306   Psychic     None

# %% [markdown]
# Which pokemon are most dense?

# %%
query = '''
SELECT * 
FROM pokemon 
WHERE weight/height > 100;'''
pds.read_sql(query, con)
# Out:
#     id      name  height  weight  base_experience   type1   type2
# 0   75  graveler      10    1050              137    Rock  Ground
# 1   76     golem      14    3000              223    Rock  Ground
# 2  111   rhyhorn      10    1150               69  Ground    Rock
# 3  143   snorlax      21    4600              189  Normal    None

# %%
query = '''
SELECT * 
FROM pokemon 
WHERE type1 IN ('Ice','Water');'''
pds.read_sql(query, con)
# Out:
#      id        name  height  weight  base_experience  type1     type2
# 0     7    squirtle       5      90               63  Water      None
# 1     8   wartortle      10     225              142  Water      None
# 2     9   blastoise      16     855              239  Water      None
# 3    54     psyduck       8     196               64  Water      None
# 4    55     golduck      17     766              175  Water      None
# 5    60     poliwag       6     124               60  Water      None
# 6    61   poliwhirl      10     200              135  Water      None
# 7    62   poliwrath      13     540              230  Water  Fighting
# 8    72   tentacool       9     455               67  Water    Poison
# 9    73  tentacruel      16     550              180  Water    Poison
# 10   79    slowpoke      12     360               63  Water   Psychic
# 11   80     slowbro      16     785              172  Water   Psychic
# 12   86        seel      11     900               65  Water      None
# 13   87     dewgong      17    1200              166  Water       Ice
# 14   90    shellder       3      40               61  Water      None
# 15   91    cloyster      15    1325              184  Water       Ice
# 16   98      krabby       4      65               65  Water      None
# 17   99     kingler      13     600              166  Water      None
# 18  116      horsea       4      80               59  Water      None
# 19  117      seadra      12     250              154  Water      None
# 20  118     goldeen       6     150               64  Water      None
# 21  119     seaking      13     390              158  Water      None
# 22  120      staryu       8     345               68  Water      None
# 23  121     starmie      11     800              182  Water   Psychic
# 24  124        jynx      14     406              159    Ice   Psychic
# 25  129    magikarp       9     100               40  Water      None
# 26  130    gyarados      65    2350              189  Water    Flying
# 27  131      lapras      25    2200              187  Water       Ice
# 28  134    vaporeon      10     290              184  Water      None
# 29  144    articuno      17     554              261    Ice    Flying

# %% [markdown]
# ### Exercise
#
# Select all the rows where "type2" is _not_ Ice or Water. Try to modify the above query to do this.

# %%
# Your code here

query = '''
SELECT * 
FROM pokemon 
WHERE type2 NOT IN ('Ice','Water') OR type2 IS NULL;
'''
pds.read_sql(query, con)
# Out:
#       id        name  height  weight  base_experience     type1    type2
# 0      1   bulbasaur       7      69               64     Grass   Poison
# 1      2     ivysaur      10     130              142     Grass   Poison
# 2      3    venusaur      20    1000              236     Grass   Poison
# 3      4  charmander       6      85               62      Fire     None
# 4      5  charmeleon      11     190              142      Fire     None
# 5      6   charizard      17     905              240      Fire   Flying
# 6      7    squirtle       5      90               63     Water     None
# 7      8   wartortle      10     225              142     Water     None
# 8      9   blastoise      16     855              239     Water     None
# 9     10    caterpie       3      29               39       Bug     None
# 10    11     metapod       7      99               72       Bug     None
# 11    12  butterfree      11     320              178       Bug   Flying
# 12    13      weedle       3      32               39       Bug   Poison
# 13    14      kakuna       6     100               72       Bug   Poison
# 14    15    beedrill      10     295              178       Bug   Poison
# 15    16      pidgey       3      18               50    Normal   Flying
# 16    17   pidgeotto      11     300              122    Normal   Flying
# 17    18     pidgeot      15     395              216    Normal   Flying
# 18    19     rattata       3      35               51    Normal     None
# 19    20    raticate       7     185              145    Normal     None
# 20    21     spearow       3      20               52    Normal   Flying
# 21    22      fearow      12     380              155    Normal   Flying
# 22    23       ekans      20      69               58    Poison     None
# 23    24       arbok      35     650              153    Poison     None
# 24    25     pikachu       4      60              112  Electric     None
# 25    26      raichu       8     300              218  Electric     None
# 26    27   sandshrew       6     120               60    Ground     None
# 27    28   sandslash      10     295              158    Ground     None
# 28    29   nidoran-f       4      70               55    Poison     None
# 29    30    nidorina       8     200              128    Poison     None
# ..   ...         ...     ...     ...              ...       ...      ...
# 114  117      seadra      12     250              154     Water     None
# 115  118     goldeen       6     150               64     Water     None
# 116  119     seaking      13     390              158     Water     None
# 117  120      staryu       8     345               68     Water     None
# 118  121     starmie      11     800              182     Water  Psychic
# 119  122     mr-mime      13     545              161   Psychic    Fairy
# 120  123     scyther      15     560              100       Bug   Flying
# 121  124        jynx      14     406              159       Ice  Psychic
# 122  125  electabuzz      11     300              172  Electric     None
# 123  126      magmar      13     445              173      Fire     None
# 124  127      pinsir      15     550              175       Bug     None
# 125  128      tauros      14     884              172    Normal     None
# 126  129    magikarp       9     100               40     Water     None
# 127  130    gyarados      65    2350              189     Water   Flying
# 128  132       ditto       3      40              101    Normal     None
# 129  133       eevee       3      65               65    Normal     None
# 130  134    vaporeon      10     290              184     Water     None
# 131  135     jolteon       8     245              184  Electric     None
# 132  136     flareon       9     250              184      Fire     None
# 133  137     porygon       8     365               79    Normal     None
# 134  142  aerodactyl      18     590              180      Rock   Flying
# 135  143     snorlax      21    4600              189    Normal     None
# 136  144    articuno      17     554              261       Ice   Flying
# 137  145      zapdos      16     526              261  Electric   Flying
# 138  146     moltres      20     600              261      Fire   Flying
# 139  147     dratini      18      33               60    Dragon     None
# 140  148   dragonair      40     165              147    Dragon     None
# 141  149   dragonite      22    2100              270    Dragon   Flying
# 142  150      mewtwo      20    1220              306   Psychic     None
# 143  151         mew       4      40              270   Psychic     None
#
# [144 rows x 7 columns]

# %% [markdown]
# ## Aggregations
#
# ![](https://img.pokemondb.net/artwork/charmander.jpg)

# %%
query = '''
SELECT count(*) 
FROM pokemon '''
pds.read_sql(query, con)
# Out:
#    count(*)
# 0       151

# %%
query = '''
SELECT sum(weight)
FROM pokemon '''
pds.read_sql(query, con)
# Out:
#    sum(weight)
# 0        69387

# %%
query = '''
SELECT sum(weight)/151.0
FROM pokemon '''
pds.read_sql(query, con)
# Out:
#    sum(weight)/151.0
# 0         459.516556

# %%
query = '''
SELECT avg(weight)
FROM pokemon '''
pds.read_sql(query, con)
# Out:
#    avg(weight)
# 0   459.516556

# %%
query = '''
SELECT min(weight),max(weight)
FROM pokemon '''
pds.read_sql(query, con)
# Out:
#    min(weight)  max(weight)
# 0            1         4600

# %% [markdown]
# ## Group By
#
# ![](https://img.pokemondb.net/artwork/magikarp.jpg)

# %%
query = '''
SELECT type1,count(*)
FROM pokemon
GROUP BY type1
ORDER BY count(*) DESC'''
pds.read_sql(query, con)
# Out:
#        type1  count(*)
# 0      Water        28
# 1     Normal        22
# 2     Poison        14
# 3        Bug        12
# 4       Fire        12
# 5      Grass        12
# 6   Electric         9
# 7       Rock         9
# 8     Ground         8
# 9    Psychic         8
# 10  Fighting         7
# 11    Dragon         3
# 12     Ghost         3
# 13     Fairy         2
# 14       Ice         2

# %%
query = '''
SELECT type1,avg(weight) as average_weight, avg(height) as average_height
FROM pokemon
GROUP BY 1'''
pds.read_sql(query, con)
# Out:
#        type1  average_weight  average_height
# 0        Bug      229.916667        9.000000
# 1     Dragon      766.000000       26.666667
# 2   Electric      317.888889        8.555556
# 3      Fairy      237.500000        9.500000
# 4   Fighting      542.857143       11.857143
# 5       Fire      480.250000       12.166667
# 6      Ghost      135.666667       14.666667
# 7      Grass      279.916667       10.833333
# 8     Ground      452.625000        8.500000
# 9        Ice      480.000000       15.500000
# 10    Normal      500.863636        9.863636
# 11    Poison      273.142857       12.214286
# 12   Psychic      515.625000       12.500000
# 13      Rock      876.111111       18.444444
# 14     Water      579.678571       13.000000

# %% [markdown]
# ### Exercise
#
# Get the count, average weight, and average height of pokemon, but grouped by Type 2.

# %%
# Your code here
query = '''
SELECT COALESCE(type2,type1), count(*), avg(weight) as average_weight, avg(height) as average_height
FROM pokemon
GROUP BY 1'''
pds.read_sql(query, con)

query = '''
SELECT type2, count(*), avg(weight) as average_weight, avg(height) as average_height
FROM pokemon
GROUP BY 1'''
pds.read_sql(query, con)
# Out:
#        type2  count(*)  average_weight  average_height
# 0       None        84      384.130952       10.488095
# 1      Fairy         3      240.000000        9.333333
# 2   Fighting         1      540.000000       13.000000
# 3     Flying        19      612.473684       16.263158
# 4      Grass         2      174.500000        6.500000
# 5     Ground         6     1261.666667       23.833333
# 6        Ice         3     1575.000000       19.000000
# 7     Poison        19      213.052632       11.000000
# 8    Psychic         6      596.000000       12.833333
# 9       Rock         2     1175.000000       14.500000
# 10     Steel         2      330.000000        6.500000
# 11     Water         4      236.250000        8.000000

# %%
query = '''
SELECT type1,min(weight)
FROM pokemon
GROUP BY type1'''
pds.read_sql(query, con)
# Out:
#        type1  min(weight)
# 0        Bug           29
# 1     Dragon           33
# 2   Electric           60
# 3      Fairy           75
# 4   Fighting          195
# 5       Fire           85
# 6      Ghost            1
# 7      Grass           25
# 8     Ground            8
# 9        Ice          406
# 10    Normal           18
# 11    Poison           10
# 12   Psychic           40
# 13      Rock           75
# 14     Water           40

# %%
query = '''
SELECT type1, avg(weight), avg(height)
FROM pokemon
GROUP BY 1'''
pds.read_sql(query, con)
# Out:
#        type1  avg(weight)  avg(height)
# 0        Bug   229.916667     9.000000
# 1     Dragon   766.000000    26.666667
# 2   Electric   317.888889     8.555556
# 3      Fairy   237.500000     9.500000
# 4   Fighting   542.857143    11.857143
# 5       Fire   480.250000    12.166667
# 6      Ghost   135.666667    14.666667
# 7      Grass   279.916667    10.833333
# 8     Ground   452.625000     8.500000
# 9        Ice   480.000000    15.500000
# 10    Normal   500.863636     9.863636
# 11    Poison   273.142857    12.214286
# 12   Psychic   515.625000    12.500000
# 13      Rock   876.111111    18.444444
# 14     Water   579.678571    13.000000

# %%
# Exact same thing, but using aliases
query = '''
SELECT type1,avg(weight) AS avg_weight, avg(height) AS avg_height
FROM pokemon
GROUP BY type1'''
pds.read_sql(query, con)
# Out:
#        type1  avg_weight  avg_height
# 0        Bug  229.916667    9.000000
# 1     Dragon  766.000000   26.666667
# 2   Electric  317.888889    8.555556
# 3      Fairy  237.500000    9.500000
# 4   Fighting  542.857143   11.857143
# 5       Fire  480.250000   12.166667
# 6      Ghost  135.666667   14.666667
# 7      Grass  279.916667   10.833333
# 8     Ground  452.625000    8.500000
# 9        Ice  480.000000   15.500000
# 10    Normal  500.863636    9.863636
# 11    Poison  273.142857   12.214286
# 12   Psychic  515.625000   12.500000
# 13      Rock  876.111111   18.444444
# 14     Water  579.678571   13.000000

# %%
query = '''
SELECT type1,type2,count(*)
FROM pokemon
GROUP BY 1,2'''
pds.read_sql(query, con)
# Out:
#        type1     type2  count(*)
# 0        Bug      None         3
# 1        Bug    Flying         2
# 2        Bug     Grass         2
# 3        Bug    Poison         5
# 4     Dragon      None         2
# 5     Dragon    Flying         1
# 6   Electric      None         6
# 7   Electric    Flying         1
# 8   Electric     Steel         2
# 9      Fairy      None         2
# 10  Fighting      None         7
# 11      Fire      None        10
# 12      Fire    Flying         2
# 13     Ghost    Poison         3
# 14     Grass      None         1
# 15     Grass    Poison         9
# 16     Grass   Psychic         2
# 17    Ground      None         6
# 18    Ground      Rock         2
# 19       Ice    Flying         1
# 20       Ice   Psychic         1
# 21    Normal      None        12
# 22    Normal     Fairy         2
# 23    Normal    Flying         8
# 24    Poison      None        10
# 25    Poison    Flying         2
# 26    Poison    Ground         2
# 27   Psychic      None         7
# 28   Psychic     Fairy         1
# 29      Rock    Flying         1
# 30      Rock    Ground         4
# 31      Rock     Water         4
# 32     Water      None        18
# 33     Water  Fighting         1
# 34     Water    Flying         1
# 35     Water       Ice         3
# 36     Water    Poison         2
# 37     Water   Psychic         3

# %% [markdown]
# ## Order By
#
# ![](https://img.pokemondb.net/artwork/jigglypuff.jpg)

# %%
query = '''
SELECT type1,avg(weight) as avg_weight, avg(height) as avg_height
FROM pokemon
GROUP BY type1
ORDER BY avg_height'''
pds.read_sql(query, con)
# Out:
#        type1  avg_weight  avg_height
# 0     Ground  452.625000    8.500000
# 1   Electric  317.888889    8.555556
# 2        Bug  229.916667    9.000000
# 3      Fairy  237.500000    9.500000
# 4     Normal  500.863636    9.863636
# 5      Grass  279.916667   10.833333
# 6   Fighting  542.857143   11.857143
# 7       Fire  480.250000   12.166667
# 8     Poison  273.142857   12.214286
# 9    Psychic  515.625000   12.500000
# 10     Water  579.678571   13.000000
# 11     Ghost  135.666667   14.666667
# 12       Ice  480.000000   15.500000
# 13      Rock  876.111111   18.444444
# 14    Dragon  766.000000   26.666667

# %%
query = '''
SELECT type1,avg(weight) as avg_weight, avg(height)
FROM pokemon
GROUP BY type1
ORDER BY avg_weight DESC'''
pds.read_sql(query, con)
# Out:
#        type1  avg_weight  avg(height)
# 0       Rock  876.111111    18.444444
# 1     Dragon  766.000000    26.666667
# 2      Water  579.678571    13.000000
# 3   Fighting  542.857143    11.857143
# 4    Psychic  515.625000    12.500000
# 5     Normal  500.863636     9.863636
# 6       Fire  480.250000    12.166667
# 7        Ice  480.000000    15.500000
# 8     Ground  452.625000     8.500000
# 9   Electric  317.888889     8.555556
# 10     Grass  279.916667    10.833333
# 11    Poison  273.142857    12.214286
# 12     Fairy  237.500000     9.500000
# 13       Bug  229.916667     9.000000
# 14     Ghost  135.666667    14.666667

# %% [markdown]
# ### Exercise
#
# What is the "type1"-"type2" combination that has the highest minimum weight in the dataset? What about the one with the lowest minimum weight?

# %%
# Your code here

query = '''
SELECT name, type1,type2,min(weight) as minimum_weight
FROM pokemon
GROUP BY 1,2
ORDER BY minimum_weight
LIMIT 1
'''
pds.read_sql(query, con)
# Out:
#      name  type1   type2  minimum_weight
# 0  gastly  Ghost  Poison               1

# %% [markdown]
# ## Having

# %%
query = '''
SELECT type1,avg(weight) as avg_weight, avg(height)
FROM pokemon
GROUP BY type1
ORDER BY avg_weight DESC'''
pds.read_sql(query, con)
# Out:
#        type1  avg_weight  avg(height)
# 0       Rock  876.111111    18.444444
# 1     Dragon  766.000000    26.666667
# 2      Water  579.678571    13.000000
# 3   Fighting  542.857143    11.857143
# 4    Psychic  515.625000    12.500000
# 5     Normal  500.863636     9.863636
# 6       Fire  480.250000    12.166667
# 7        Ice  480.000000    15.500000
# 8     Ground  452.625000     8.500000
# 9   Electric  317.888889     8.555556
# 10     Grass  279.916667    10.833333
# 11    Poison  273.142857    12.214286
# 12     Fairy  237.500000     9.500000
# 13       Bug  229.916667     9.000000
# 14     Ghost  135.666667    14.666667

# %% [markdown]
# ### Exercise
#
# Show all the "type2" categories that have a minimum height of greater than 10. Create a CSV that contains all these categories.
#
# Which of these types has the highest maximum height?

# %%
# Your code here

query = '''
SELECT type2, min(height) as min_height, max(height) as max_height
FROM pokemon
GROUP BY 1
HAVING min_height > 10
ORDER by max_height DESC
'''
tiny_dataframe = pds.read_sql(query, con)
tiny_dataframe.to_csv('tall_pokemon_types.csv')

# %% [markdown]
# ![](https://sqlite.org/images/syntax/select-core.gif)
