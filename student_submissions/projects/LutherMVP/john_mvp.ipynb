# %% [markdown]
# **Predicting Movie IMDB Ratings**

# %%
Image('budget_vs_rating.png')

# %%
Image('runtime_vs_rating.png')

# %% [markdown]
# Simple analysis of only budget and runtime do not tell us much about a movie's IMDB rating, but by adding genres and polynomial features to the budget and runtime data, we are able to use linear regression to predict a movie's IMDB rating with a RMSE of about 1. IMDB rating are on a scale of 1 to 10 so the predictions are better than expected and suggests promising results with further exploration of directors/writers/actors.

# %%
from IPython.display import Image
