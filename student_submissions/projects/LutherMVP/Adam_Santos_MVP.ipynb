# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The above plot shows the baseline for my model predicting graduation rates for high schools in New York City. The model uses a single feature, Average Daily Attendance, to do so. The r-squared score is 0.57 using this one feature. I will try to improve this score by adding other features. Once I feel I cannot improve the score further, I will pick out important features to communicate those to schools.
