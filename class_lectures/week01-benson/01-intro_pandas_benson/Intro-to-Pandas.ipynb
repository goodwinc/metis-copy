# %%
# Python 2 & 3 Compatibility
from __future__ import print_function, division

# %% [markdown]
# # Introduction to Pandas
#
# **Learning Goals**: Review / introduce pandas syntax that allows us to work with and extract information from data. Covering the following 4 areas in particular:
#
# 1. Reading, previewing, formatting data (e.g. `pd.read_csv`, `.head`)
# 2. Summarizing (e.g. `.describe`)
# 3. Selecting / filtering (`.loc` and `.iloc`, boolean series filters)
# 4. Basic manipulation (e.g. `.groupby` aggregations)

# %% [markdown]
# ###  Wait, what the heck is pandas?
#
# Pandas library: provides several data structures that makes working with relational data
# both easy & intuitive--

# %% [markdown]
# ## From the Pandas documentation:
#
# Here are just a few of the things that pandas does well:
#
# - Easy handling of **missing data** (represented as NaN) in floating point as well as non-floating point data
# - Size mutability: columns can be **inserted and deleted** from DataFrame and higher dimensional objects
# - Automatic and explicit **data alignment**: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
# - Powerful, flexible **group by** functionality to perform split-apply-combine operations on data sets, for both aggregating and transforming data
# - Make it **easy to convert** ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
# - Intelligent **label-based slicing**, **fancy indexing**, and **subsetting** of large data sets
# - Intuitive **merging** and **joining** data sets
# - Flexible **reshaping** and **pivoting** of data sets
# - **Hierarchical labeling** of axes (possible to have multiple labels per tick)
# - **Robust IO tools** for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format
# - **Time series**-specific functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging, etc.

# %% [markdown]
# ### 10 Minutes Intro to Pandas ###
# http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# ## Set up Pandas default params

# %%
# imports a library 'pandas', names it as 'pd'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 0.23.4
# Numpy version: 1.14.1

# %%
# various options in pandas
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 3)

# %% [markdown]
# ## Data structures
#
# ### 1. Series
#
# One Dimensional Array / Vector of Values (Think of these as your data columns).  One important aspect of them is that they carry an "index" (which you can think of as a row indicator).
#
# ### 2. Dataframes
#
# Think of DataFrame as a Table with Columns.  This is the workhorse of everything you will do with data analysis.  Learning Pandas and its functions can be challenging, but stick with it and ask questions.  Structurally, a DataFrame can be thought of as a collection of Series objects with the same index.

# %%
## Make a Series, one of which is a float
s = pd.Series([1,3,5,np.nan,6,8])

s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# get details on DataFrame: use shift-tab!
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
## Make a dataframe from a numpy array
df1 = pd.DataFrame(np.random.randn(6,4), columns=list('ABCD')) 
df1
# Out:
#        A      B      C      D
# 0  1.144  0.022 -0.386  0.433
# 1  0.123 -1.063  0.148  1.414
# 2  0.630  0.107 -0.006  0.078
# 3 -0.781 -0.169  0.499  0.864
# 4  0.364 -0.945  0.319  1.190
# 5 -1.799  0.516 -1.722 -0.381

# %%
## Make a dataframe from a dictionary

df2 = pd.DataFrame({ 'A' : 1., \
                    'B' : pd.Timestamp('20130102'), \
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'), \
                    'D' : np.array([3] * 4,dtype='int32'), \
                    'E' : pd.Categorical(["test","train","test","train"]), \
                    'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ## Load a data set -- read_*

# %% [markdown]
# ### "Census Income" dataset
#
# http://archive.ics.uci.edu/ml/
# pandas can load a lot more than csvs, this tutorial shows how pandas can read excel, sql, and even copy and paste...
# http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/

# %%
# download the data and name the columns
cols = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
        'marital_status', 'occupation', 'relationship', 'ethnicity',
        'gender', 'capital_gain', 'capital_loss', 'hours_per_week',
        'country_of_origin', 'income']

df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',
                 names = cols)

# adult dataset ~ Uci : prediction dataset for income above/below $50K..

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# 0          2174             0              40     United-States   <=50K
# 1             0             0              13     United-States   <=50K
# 2             0             0              40     United-States   <=50K
# 3             0             0              40     United-States   <=50K
# 4             0             0              40              Cuba   <=50K

# %% [markdown]
# **Q: What's happening in the above cell?**

# %% [markdown]
# ## Viewing Data
#
# * .info()
# * .head()
# * .tail()
# * .columns
# * .values
# * .dtype

# %% [markdown]
# ### info
#
# Displays the Columns, Types, Rows and the memory used by the dataframe

# %%
# we can see there are no null values
# columns with numerical values are type int64, no need to set data type (pandas will infer..)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                  32561 non-null int64
# workclass            32561 non-null object
# fnlwgt               32561 non-null int64
# education            32561 non-null object
# education_num        32561 non-null int64
# marital_status       32561 non-null object
# occupation           32561 non-null object
# relationship         32561 non-null object
# ethnicity            32561 non-null object
# gender               32561 non-null object
# capital_gain         32561 non-null int64
# capital_loss         32561 non-null int64
# hours_per_week       32561 non-null int64
# country_of_origin    32561 non-null object
# income               32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# Pandas Datatypes
# http://www.datacarpentry.org/python-ecology-lesson/03-data-types-and-format/

# %% [markdown]
# ### Head
# Displays the first few rows in the dataframe

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# 0          2174             0              40     United-States   <=50K
# 1             0             0              13     United-States   <=50K
# 2             0             0              40     United-States   <=50K
# 3             0             0              40     United-States   <=50K
# 4             0             0              40              Cuba   <=50K

# %%
# of course, we can also use shift + tab!
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index, columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#
#         .. versionadded:: 0.21.0
#     level : int or level name, optional
#         For MultiIndex, level from which the labels will be removed.
#     inplace : bool, default False
#         If True, do operation inplace and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and only existing labels are
#         dropped.
#
#     Returns
#     -------
#     dropped : pandas.DataFrame
#
#     See Also
#     --------
#     DataFrame.loc : Label-location based indexer for selection by label.
#     DataFrame.dropna : Return DataFrame with labels on given axis omitted
#         where (all or any) data are missing
#     DataFrame.drop_duplicates : Return DataFrame with duplicate rows
#         removed, optionally only considering certain columns
#     Series.drop : Return Series with specified index labels removed.
#
#     Raises
#     ------
#     KeyError
#         If none of the labels are found in the selected axis
#
#     Examples
#     --------
#     >>> df = pd.DataFrame(np.arange(12).reshape(3,4),
#     ...                   columns=['A', 'B', 'C', 'D'])
#     >>> df
#        A  B   C   D
#     0  0  1   2   3
#     1  4  5   6   7
#     2  8  9  10  11
#
#     Drop columns
#
#     >>> df.drop(['B', 'C'], axis=1)
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     >>> df.drop(columns=['B', 'C'])
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     Drop a row by index
#
#     >>> df.drop([0, 1])
#        A  B   C   D
#     2  8  9  10  11
#
#     Drop columns and/or rows of MultiIndex DataFrame
#
#     >>> midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
#     ...                              ['speed', 'weight', 'length']],
#     ...                      labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
#     ...                              [0, 1, 2, 0, 1, 2, 0, 1, 2]])
#     >>> df = pd.DataFrame(index=midx, columns=['big', 'small'],
#     ...                   data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
#     ...                         [250, 150], [1.5, 0.8], [320, 250],
#     ...                         [1, 0.8], [0.3,0.2]])
#     >>> df
#                     big     small
#     lama    speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8
#             length  0.3     0.2
#
#     >>> df.drop(index='cow', columns='small')
#                     big
#     lama    speed   45.0
#             weight  200.0
#             length  1.5
#     falcon  speed   320.0
#             weight  1.0
#             length  0.3
#
#     >>> df.drop(index='length', level=1)
#                     big     small
#     lama    speed   45.0    30.0
#             weight  200.0   100.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                  32561 non-null int64
# workclass            32561 non-null object
# fnlwgt               32561 non-null int64
# education            32561 non-null object
# education_num        32561 non-null int64
# marital_status       32561 non-null object
# occupation           32561 non-null object
# relationship         32561 non-null object
# ethnicity            32561 non-null object
# gender               32561 non-null object
# capital_gain         32561 non-null int64
# capital_loss         32561 non-null int64
# hours_per_week       32561 non-null int64
# country_of_origin    32561 non-null object
# income               32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %%
newdf = df.drop('hours_per_week',axis=1)

df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
# age                  32561 non-null int64
# workclass            32561 non-null object
# fnlwgt               32561 non-null int64
# education            32561 non-null object
# education_num        32561 non-null int64
# marital_status       32561 non-null object
# occupation           32561 non-null object
# relationship         32561 non-null object
# ethnicity            32561 non-null object
# gender               32561 non-null object
# capital_gain         32561 non-null int64
# capital_loss         32561 non-null int64
# country_of_origin    32561 non-null object
# income               32561 non-null object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                  32561 non-null int64
# workclass            32561 non-null object
# fnlwgt               32561 non-null int64
# education            32561 non-null object
# education_num        32561 non-null int64
# marital_status       32561 non-null object
# occupation           32561 non-null object
# relationship         32561 non-null object
# ethnicity            32561 non-null object
# gender               32561 non-null object
# capital_gain         32561 non-null int64
# capital_loss         32561 non-null int64
# hours_per_week       32561 non-null int64
# country_of_origin    32561 non-null object
# income               32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# to view the first 5 or specify with ex: .head(10)
df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship ethnicity  \
# 0           Never-married        Adm-clerical   Not-in-family     White
# 1      Married-civ-spouse     Exec-managerial         Husband     White
# 2                Divorced   Handlers-cleaners   Not-in-family     White
# 3      Married-civ-spouse   Handlers-cleaners         Husband     Black
# 4      Married-civ-spouse      Prof-specialty            Wife     Black
# 5      Married-civ-spouse     Exec-managerial            Wife     White
# 6   Married-spouse-absent       Other-service   Not-in-family     Black
# 7      Married-civ-spouse     Exec-managerial         Husband     White
# 8           Never-married      Prof-specialty   Not-in-family     White
# 9      Married-civ-spouse     Exec-managerial         Husband     White
#
#     gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 0     Male          2174             0              40     United-States
# 1     Male             0             0              13     United-States
# 2     Male             0             0              40     United-States
# 3     Male             0             0              40     United-States
# 4   Female             0             0              40              Cuba
# 5   Female             0             0              40     United-States
# 6   Female             0             0              16           Jamaica
# 7     Male             0             0              45     United-States
# 8   Female         14084             0              50     United-States
# 9     Male          5178             0              40     United-States
#
#    income
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K
# 5   <=50K
# 6   <=50K
# 7    >50K
# 8    >50K
# 9    >50K

# %% [markdown]
# ### Tail
#
# Displays the last few rows in the dataframe

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship ethnicity  \
# 32556   Married-civ-spouse        Tech-support         Wife     White
# 32557   Married-civ-spouse   Machine-op-inspct      Husband     White
# 32558              Widowed        Adm-clerical    Unmarried     White
# 32559        Never-married        Adm-clerical    Own-child     White
# 32560   Married-civ-spouse     Exec-managerial         Wife     White
#
#         gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 32556   Female             0             0              38     United-States
# 32557     Male             0             0              40     United-States
# 32558   Female             0             0              40     United-States
# 32559     Male             0             0              20     United-States
# 32560   Female         15024             0              40     United-States
#
#        income
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K

# %% [markdown]
# ### Sample
#
# Displays a Sample of rows in the dataframe

# %%
# head and tail are good.  But sometimes we want to randomly sample data
df.sample(5, random_state=42)
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 14160   27            Private  160178   Some-college             10
# 27048   45          State-gov   50567        HS-grad              9
# 28868   29            Private  185908      Bachelors             13
# 5667    30            Private  190040      Bachelors             13
# 7827    29   Self-emp-not-inc  189346   Some-college             10
#
#             marital_status          occupation    relationship ethnicity  \
# 14160             Divorced        Adm-clerical   Not-in-family     White
# 27048   Married-civ-spouse     Exec-managerial            Wife     White
# 28868   Married-civ-spouse     Exec-managerial         Husband     Black
# 5667         Never-married   Machine-op-inspct   Not-in-family     White
# 7827              Divorced        Craft-repair   Not-in-family     White
#
#         gender  capital_gain  capital_loss  hours_per_week country_of_origin  \
# 14160   Female             0             0              38     United-States
# 27048   Female             0             0              40     United-States
# 28868     Male             0             0              55     United-States
# 5667    Female             0             0              40     United-States
# 7827      Male          2202             0              50     United-States
#
#        income
# 14160   <=50K
# 27048   <=50K
# 28868    >50K
# 5667    <=50K
# 7827    <=50K

# %% [markdown]
# ### Columns
#
# Returns a List of Columns in the dataframe

# %%
# view all columns of the dataframe
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %% [markdown]
# ### Column Types
#
# Returns the type of each column

# %%
df.dtypes
# Out:
# age                   int64
# workclass            object
# fnlwgt                int64
# education            object
# education_num         int64
# marital_status       object
# occupation           object
# relationship         object
# ethnicity            object
# gender               object
# capital_gain          int64
# capital_loss          int64
# hours_per_week        int64
# country_of_origin    object
# income               object
# dtype: object

# %% [markdown]
# ## Rename columns

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %%
# elaborate on inplace .. 
df.columns
df.rename(columns = {'country_of_origin' : 'native_country'}).head(1)
# Out:
#    age   workclass  fnlwgt   education  education_num  marital_status  \
# 0   39   State-gov   77516   Bachelors             13   Never-married
#
#       occupation    relationship ethnicity gender  capital_gain  capital_loss  \
# 0   Adm-clerical   Not-in-family     White   Male          2174             0
#
#    hours_per_week  native_country  income
# 0              40   United-States   <=50K

# %%
# aha.. but it's not actually renamed ?! 
df.head()

## df.rename( ~ inplace=False by default)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# 0          2174             0              40     United-States   <=50K
# 1             0             0              13     United-States   <=50K
# 2             0             0              40     United-States   <=50K
# 3             0             0              40     United-States   <=50K
# 4             0             0              40              Cuba   <=50K

# %%
# replace a column name, (inplace = True, allows us to rename w/out saying df= df.)
df.rename(columns = {'country_of_origin' : 'native_country'}, inplace = True)

# or .. df=df.rename(columns = {'country_of_origin' : 'native_country'})
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %% [markdown]
# ## Descriptives
#
# * .describe()
# * .value_counts()
# * .mean()
# * .unique()

# %% [markdown]
# ### Describe
#
# Displays summary statistic for each Numerical column

# %%
df.describe()
# Out:
#              age     fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000  3.256e+04      32561.000     32561.000     32561.000
# mean      38.582  1.898e+05         10.081      1077.649        87.304
# std       13.640  1.055e+05          2.573      7385.292       402.960
# min       17.000  1.228e+04          1.000         0.000         0.000
# 25%       28.000  1.178e+05          9.000         0.000         0.000
# 50%       37.000  1.784e+05         10.000         0.000         0.000
# 75%       48.000  2.371e+05         12.000         0.000         0.000
# max       90.000  1.485e+06         16.000     99999.000      4356.000
#
#        hours_per_week
# count       32561.000
# mean           40.437
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %% [markdown]
# ### value_counts
#
# Counts the number of occurances of each categorical value for the column

# %%
df['education']
# Out:
# 0            Bachelors
# 1            Bachelors
# 2              HS-grad
# 3                 11th
# 4            Bachelors
# 5              Masters
# 6                  9th
# 7              HS-grad
# 8              Masters
# 9            Bachelors
# 10        Some-college
# 11           Bachelors
#              ...
# 32549     Some-college
# 32550     Some-college
# 32551             10th
# 32552        Assoc-voc
# 32553          Masters
# 32554          Masters
# 32555     Some-college
# 32556       Assoc-acdm
# 32557          HS-grad
# 32558          HS-grad
# 32559          HS-grad
# 32560          HS-grad
# Name: education, Length: 32561, dtype: object

# %%
type(df.education)
# Out:
# pandas.core.series.Series

# %%
df.education.value_counts()

## Also works for numeric columns - treating the individual values as factors
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df.education.value_counts().plot('barh')

# %%
df.hours_per_week.mean()

# Can also do:
df['hours_per_week'].mean()
# Out:
# 40.437455852092995

# %% [markdown]
# ## Comprehension Question:
#
# What do you think we will get if we ask for the `type` of `df.hours_per_week` ?

# %%
# we can extract a subset of columns..
df[['age', 'capital_gain', 'capital_loss', 'hours_per_week']].describe()
# Out:
#              age  capital_gain  capital_loss  hours_per_week
# count  32561.000     32561.000     32561.000       32561.000
# mean      38.582      1077.649        87.304          40.437
# std       13.640      7385.292       402.960          12.347
# min       17.000         0.000         0.000           1.000
# 25%       28.000         0.000         0.000          40.000
# 50%       37.000         0.000         0.000          40.000
# 75%       48.000         0.000         0.000          45.000
# max       90.000     99999.000      4356.000          99.000

# %% [markdown]
# ### Unique
#
# Returns the unique values for the column

# %%
# there's a space before each string in this data
df.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
# looks like it's in every object column
df.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
# let's remove that space .. 

df["education"] = df.education.str.strip()

# %%
# Hurray! 
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# ethnicity         32561 non-null object
# gender            32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.education_num.value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education_num, dtype: int64

# %%
df.gender.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
# Remove leading space in values
df["gender"] = df.gender.str.strip()

# %%
df.gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## Selecting rows and columns

# %% [markdown]
# ### .loc
#
# * Selects row and columns by Names
# * **by label**             `.loc[]`
#
# ### .iloc
#
# * Selects row and columns by Index Position
# * **by integer position**  `.iloc[]`

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/indexing.html

# %%
df.head(5)
# Out:
#    age          workclass  fnlwgt  education  education_num  \
# 0   39          State-gov   77516  Bachelors             13
# 1   50   Self-emp-not-inc   83311  Bachelors             13
# 2   38            Private  215646    HS-grad              9
# 3   53            Private  234721       11th              7
# 4   28            Private  338409  Bachelors             13
#
#         marital_status          occupation    relationship ethnicity  gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White    Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White    Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White    Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black    Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black  Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
# select a row

## What do you think this output will be  ? 

df.iloc[3]
# Out:
# age                                53
# workclass                     Private
# fnlwgt                         234721
# education                        11th
# education_num                       7
# marital_status     Married-civ-spouse
# occupation          Handlers-cleaners
# relationship                  Husband
# ethnicity                       Black
# gender                           Male
# capital_gain                        0
# capital_loss                        0
# hours_per_week                     40
# native_country          United-States
# income                          <=50K
# Name: 3, dtype: object

# %%
df.iloc[0:3]

## Note: I got 3 rows returned, similar to the indexing that applies to Python lists
# Out:
#    age          workclass  fnlwgt  education  education_num  \
# 0   39          State-gov   77516  Bachelors             13
# 1   50   Self-emp-not-inc   83311  Bachelors             13
# 2   38            Private  215646    HS-grad              9
#
#         marital_status          occupation    relationship ethnicity gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
# select a range of rows
df.iloc[10:15]
# Out:
#     age   workclass  fnlwgt     education  education_num       marital_status  \
# 10   37     Private  280464  Some-college             10   Married-civ-spouse
# 11   30   State-gov  141297     Bachelors             13   Married-civ-spouse
# 12   23     Private  122272     Bachelors             13        Never-married
# 13   32     Private  205019    Assoc-acdm             12        Never-married
# 14   40     Private  121772     Assoc-voc             11   Married-civ-spouse
#
#           occupation    relationship            ethnicity  gender  \
# 10   Exec-managerial         Husband                Black    Male
# 11    Prof-specialty         Husband   Asian-Pac-Islander    Male
# 12      Adm-clerical       Own-child                White  Female
# 13             Sales   Not-in-family                Black    Male
# 14      Craft-repair         Husband   Asian-Pac-Islander    Male
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 10             0             0              80   United-States    >50K
# 11             0             0              40           India    >50K
# 12             0             0              30   United-States   <=50K
# 13             0             0              50   United-States   <=50K
# 14             0             0              40               ?    >50K

# %%
# last 2 rows
df.iloc[-2:]
# Out:
#        age      workclass  fnlwgt education  education_num  \
# 32559   22        Private  201490   HS-grad              9
# 32560   52   Self-emp-inc  287927   HS-grad              9
#
#             marital_status        occupation relationship ethnicity  gender  \
# 32559        Never-married      Adm-clerical    Own-child     White    Male
# 32560   Married-civ-spouse   Exec-managerial         Wife     White  Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K

# %%
# selecting every other row in columns 3-5
df.iloc[::2, 2:5].head()
# Out:
#    fnlwgt  education  education_num
# 0   77516  Bachelors             13
# 2  215646    HS-grad              9
# 4  338409  Bachelors             13
# 6  160187        9th              5
# 8   45781    Masters             14

# %%
df_2=df.set_index('fnlwgt')
df_2.head()
# Out:
#         age          workclass  education  education_num       marital_status  \
# fnlwgt
# 77516    39          State-gov  Bachelors             13        Never-married
# 83311    50   Self-emp-not-inc  Bachelors             13   Married-civ-spouse
# 215646   38            Private    HS-grad              9             Divorced
# 234721   53            Private       11th              7   Married-civ-spouse
# 338409   28            Private  Bachelors             13   Married-civ-spouse
#
#                 occupation    relationship ethnicity  gender  capital_gain  \
# fnlwgt
# 77516         Adm-clerical   Not-in-family     White    Male          2174
# 83311      Exec-managerial         Husband     White    Male             0
# 215646   Handlers-cleaners   Not-in-family     White    Male             0
# 234721   Handlers-cleaners         Husband     Black    Male             0
# 338409      Prof-specialty            Wife     Black  Female             0
#
#         capital_loss  hours_per_week  native_country  income
# fnlwgt
# 77516              0              40   United-States   <=50K
# 83311              0              13   United-States   <=50K
# 215646             0              40   United-States   <=50K
# 234721             0              40   United-States   <=50K
# 338409             0              40            Cuba   <=50K

# %%
# select a row
df_2.loc[77516]
# Out:
# age                           39
# workclass              State-gov
# education              Bachelors
# education_num                 13
# marital_status     Never-married
# occupation          Adm-clerical
# relationship       Not-in-family
# ethnicity                  White
# gender                      Male
# capital_gain                2174
# capital_loss                   0
# hours_per_week                40
# native_country     United-States
# income                     <=50K
# Name: 77516, dtype: object

# %%
df_2.loc[[77516,338409], 'age']
# Out:
# fnlwgt
# 77516     39
# 338409    28
# Name: age, dtype: int64

# %% [markdown]
# ## Filtering

# %% [markdown]
# For filtering, our best friend will be a **boolean series**, i.e. a pandas series of True and False values. We can easily create one by checking a condition against an existing series, like below.

# %%
(df.age > 50)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
#          ...
# 32549    False
# 32550    False
# 32551    False
# 32552    False
# 32553    False
# 32554     True
# 32555    False
# 32556    False
# 32557    False
# 32558     True
# 32559    False
# 32560     True
# Name: age, Length: 32561, dtype: bool

# %% [markdown]
# Such a series can then be used to extract a subset from a dataframe (implicitly using `.loc`), so long as the boolean filter series has the exact same index as the dataframe. This returns only the rows of the dataframe that correspond to the `True` values in the boolean series.

# %%
# generate a subset of our data based on a filter, 

asd = df[df.age > 50].head(5)
asd
# Out:
#     age          workclass  fnlwgt  education  education_num  \
# 3    53            Private  234721       11th              7
# 7    52   Self-emp-not-inc  209642    HS-grad              9
# 21   54            Private  302146    HS-grad              9
# 24   59            Private  109015    HS-grad              9
# 25   56          Local-gov  216851  Bachelors             13
#
#          marital_status          occupation relationship ethnicity  gender  \
# 3    Married-civ-spouse   Handlers-cleaners      Husband     Black    Male
# 7    Married-civ-spouse     Exec-managerial      Husband     White    Male
# 21            Separated       Other-service    Unmarried     Black  Female
# 24             Divorced        Tech-support    Unmarried     White  Female
# 25   Married-civ-spouse        Tech-support      Husband     White    Male
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 3              0             0              40   United-States   <=50K
# 7              0             0              45   United-States    >50K
# 21             0             0              20   United-States   <=50K
# 24             0             0              40   United-States   <=50K
# 25             0             0              40   United-States    >50K

# %%
# Filter for only certain Columns
df.loc[df.age > 50, ['age', 'education', 'occupation', 'gender', 'income']]

# What happens if I try to do the same with df.iloc instead of df.loc?
# What about df.ix?
# Out:
#        age     education          occupation  gender  income
# 3       53          11th   Handlers-cleaners    Male   <=50K
# 7       52       HS-grad     Exec-managerial    Male    >50K
# 21      54       HS-grad       Other-service  Female   <=50K
# 24      59       HS-grad        Tech-support  Female   <=50K
# 25      56     Bachelors        Tech-support    Male    >50K
# 27      54  Some-college                   ?    Male    >50K
# 41      53     Bachelors      Prof-specialty    Male   <=50K
# 45      57     Bachelors      Prof-specialty    Male    >50K
# 46      53       HS-grad   Machine-op-inspct    Male   <=50K
# 67      53       HS-grad        Adm-clerical  Female    >50K
# 74      79  Some-college      Prof-specialty    Male   <=50K
# 77      67          10th                   ?    Male   <=50K
# ...    ...           ...                 ...     ...     ...
# 32501   71           9th       Other-service    Male   <=50K
# 32515   66          10th        Craft-repair    Male   <=50K
# 32518   57       HS-grad        Craft-repair    Male    >50K
# 32522   58          11th               Sales    Male   <=50K
# 32525   81     Assoc-voc                   ?  Female   <=50K
# 32533   54     Bachelors     Exec-managerial    Male    >50K
# 32539   71     Doctorate                   ?    Male    >50K
# 32542   72       HS-grad                   ?    Male   <=50K
# 32548   65   Prof-school      Prof-specialty    Male   <=50K
# 32554   53       Masters     Exec-managerial    Male    >50K
# 32558   58       HS-grad        Adm-clerical  Female   <=50K
# 32560   52       HS-grad     Exec-managerial  Female    >50K
#
# [6460 rows x 5 columns]

# %%
df[df.age > 50].head(4)
# Out:
#     age          workclass  fnlwgt education  education_num  \
# 3    53            Private  234721      11th              7
# 7    52   Self-emp-not-inc  209642   HS-grad              9
# 21   54            Private  302146   HS-grad              9
# 24   59            Private  109015   HS-grad              9
#
#          marital_status          occupation relationship ethnicity  gender  \
# 3    Married-civ-spouse   Handlers-cleaners      Husband     Black    Male
# 7    Married-civ-spouse     Exec-managerial      Husband     White    Male
# 21            Separated       Other-service    Unmarried     Black  Female
# 24             Divorced        Tech-support    Unmarried     White  Female
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 3              0             0              40   United-States   <=50K
# 7              0             0              45   United-States    >50K
# 21             0             0              20   United-States   <=50K
# 24             0             0              40   United-States   <=50K

# %% [markdown]
# ## Now Filter on Gender

# %%
df.gender==' Male'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
#          ...
# 32549    False
# 32550    False
# 32551    False
# 32552    False
# 32553    False
# 32554    False
# 32555    False
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: gender, Length: 32561, dtype: bool

# %%
df[df.age > 50].head(4)
# Out:
#     age          workclass  fnlwgt education  education_num  \
# 3    53            Private  234721      11th              7
# 7    52   Self-emp-not-inc  209642   HS-grad              9
# 21   54            Private  302146   HS-grad              9
# 24   59            Private  109015   HS-grad              9
#
#          marital_status          occupation relationship ethnicity  gender  \
# 3    Married-civ-spouse   Handlers-cleaners      Husband     Black    Male
# 7    Married-civ-spouse     Exec-managerial      Husband     White    Male
# 21            Separated       Other-service    Unmarried     Black  Female
# 24             Divorced        Tech-support    Unmarried     White  Female
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# 3              0             0              40   United-States   <=50K
# 7              0             0              45   United-States    >50K
# 21             0             0              20   United-States   <=50K
# 24             0             0              40   United-States   <=50K

# %%
# originally : ~ ' Male'
subs=df[df.gender.str.strip() =='Male']
subs.head()
# Out:
#    age          workclass  fnlwgt  education  education_num  \
# 0   39          State-gov   77516  Bachelors             13
# 1   50   Self-emp-not-inc   83311  Bachelors             13
# 2   38            Private  215646    HS-grad              9
# 3   53            Private  234721       11th              7
# 7   52   Self-emp-not-inc  209642    HS-grad              9
#
#         marital_status          occupation    relationship ethnicity gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband     White   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 7             0             0              45   United-States    >50K

# %% [markdown]
# ## Now Filter on Gender and Age between 30 and 40

# %% [markdown]
# We can also chain together multiple conditions into one boolean series filter, like below. Note the use of element-wise and (`&`) instead of the usual python `and`, this is required.

# %%
(df.gender == 'Male') & (df.age>=30) & (df.age<=40)
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10        True
# 11        True
#          ...
# 32549    False
# 32550    False
# 32551     True
# 32552    False
# 32553     True
# 32554    False
# 32555    False
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
(df.age>=30)&(df.gender=='Male')

# we can use a Boolean for our loc label
# .loc let's us specify our columns with ':'
df.loc[(df.age>=30)&(df.gender=='Male')&(df.age<=40),:];

# %%
# can also do like this.. 
a=df[(df.age>=30)&(df.gender=='Male')&(df.age<=40)]

# %% [markdown]
# ## Find Nulls

# %%
# as we saw with df.info() there are no nulls... 
# but if there were this would find the rows where age is null
df[df.age.isnull()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education_num, marital_status, occupation, relationship, ethnicity, gender, capital_gain, capital_loss, hours_per_week, native_country, income]
# Index: []

# %% [markdown]
# ## Fill nulls

# %%
null_df = pd.DataFrame([1,2,4,np.nan], columns = ['column1'])

# %%
null_df
# Out:
#    column1
# 0      1.0
# 1      2.0
# 2      4.0
# 3      NaN

# %%
# you can also fill nulls with a value or string
null_df.column1.fillna(1000)
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3    1000.0
# Name: column1, dtype: float64

# %%
# fillna does not do it inplace unless you specify
null_df
# Out:
#    column1
# 0      1.0
# 1      2.0
# 2      4.0
# 3      NaN

# %%
# you can also fill null with the median or mean value of the column
null_df.fillna(null_df.column1.median())
# Out:
#    column1
# 0      1.0
# 1      2.0
# 2      4.0
# 3      2.0

# %%
null_df.fillna('random_string')
# Out:
#          column1
# 0              1
# 1              2
# 2              4
# 3  random_string

# %% [markdown]
# ## Drop nulls

# %%
null_df = pd.DataFrame([1,2,4,np.nan], columns = ['column1'])
null_df
# Out:
#    column1
# 0      1.0
# 1      2.0
# 2      4.0
# 3      NaN

# %%
# drop a row that has any occurence of a null value
null_df.dropna(how = 'any')
# Out:
#    column1
# 0      1.0
# 1      2.0
# 2      4.0

# %%
# .isnull() and .notnull() do opposite things
null_df.isnull()
# Out:
#    column1
# 0    False
# 1    False
# 2    False
# 3     True

# %%
null_df.notnull()
# Out:
#    column1
# 0     True
# 1     True
# 2     True
# 3    False

# %% [markdown]
# ## Groupby

# %%
gb=df.groupby('relationship').count()
gb
# Out:
#                    age  workclass  fnlwgt  education  education_num  \
# relationship
#  Husband         13193      13193   13193      13193          13193
#  Not-in-family    8305       8305    8305       8305           8305
#  Other-relative    981        981     981        981            981
#  Own-child        5068       5068    5068       5068           5068
#  Unmarried        3446       3446    3446       3446           3446
#  Wife             1568       1568    1568       1568           1568
#
#                  marital_status  occupation  ethnicity  gender  capital_gain  \
# relationship
#  Husband                  13193       13193      13193   13193         13193
#  Not-in-family             8305        8305       8305    8305          8305
#  Other-relative             981         981        981     981           981
#  Own-child                 5068        5068       5068    5068          5068
#  Unmarried                 3446        3446       3446    3446          3446
#  Wife                      1568        1568       1568    1568          1568
#
#                  capital_loss  hours_per_week  native_country  income
# relationship
#  Husband                13193           13193           13193   13193
#  Not-in-family           8305            8305            8305    8305
#  Other-relative           981             981             981     981
#  Own-child               5068            5068            5068    5068
#  Unmarried               3446            3446            3446    3446
#  Wife                    1568            1568            1568    1568

# %%
 # does order matter of groupby keys matter ? 
    
df.groupby(['education','age'])[['hours_per_week','capital_gain']].mean()
# Out:
#                   hours_per_week  capital_gain
# education    age
# 10th         17           21.543       266.659
#              18           27.895         0.000
#              19           34.500         0.000
#              20           39.400         0.000
#              21           39.000       229.882
#              22           37.053         0.000
#              23           42.588         0.000
#              24           41.889         0.000
#              25           38.714       123.667
#              26           42.706       171.000
#              27           46.059         0.000
#              28           39.914         0.000
# ...                          ...           ...
# Some-college 74           19.727      1822.818
#              75           23.750         0.000
#              76           23.714         0.000
#              77           22.143         0.000
#              78            3.000         0.000
#              79           20.000         0.000
#              80           40.000         0.000
#              81           13.000         0.000
#              82           11.500         0.000
#              84           35.000         0.000
#              88           40.000         0.000
#              90           32.833         0.000
#
# [965 rows x 2 columns]

# %%
# only matters: bc data display will be altered ..

# %%
# To groupby multiple columns with multiple functions attached
df.groupby(['income', 'native_country']).age.agg(['count', 'mean'])
# grouped in order of which column is listed first
# Out:
#                             count    mean
# income native_country
#  <=50K  ?                     437  36.854
#         Cambodia               12  35.667
#         Canada                 82  41.012
#         China                  55  41.800
#         Columbia               57  39.228
#         Cuba                   70  47.286
#         Dominican-Republic     68  37.941
#         Ecuador                24  34.833
#         El-Salvador            97  32.649
#         England                60  38.967
#         France                 17  38.118
#         Germany                93  36.817
# ...                           ...     ...
#  >50K   Philippines            61  42.738
#         Poland                 12  50.583
#         Portugal                4  40.000
#         Puerto-Rico            12  46.500
#         Scotland                3  52.667
#         South                  16  44.875
#         Taiwan                 20  40.800
#         Thailand                3  32.667
#         Trinadad&Tobago         2  42.500
#         United-States        7171  44.297
#         Vietnam                 5  35.400
#         Yugoslavia              6  40.167
#
# [82 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
# can use the aggs function to aggregate columns seperately
gb=df.groupby(['income', 'native_country'])
gb_aggs=gb.agg({'age':'mean','capital_gain':'sum'})
gb_aggs.head()
# Out:
#                           age  capital_gain
# income native_country
#  <=50K  ?              36.854         49712
#         Cambodia       35.667          5979
#         Canada         41.012          9077
#         China          41.800          5714
#         Columbia       39.228         10656

# %%
# combine groupby with boolean
df[df.native_country == ' United-States'].groupby(['education']).hours_per_week.mean()
# Out:
# education
# 10th            36.915
# 11th            33.682
# 12th            34.951
# 1st-4th         32.913
# 5th-6th         36.979
# 7th-8th         39.060
# 9th             38.035
# Assoc-acdm      40.657
# Assoc-voc       41.633
# Bachelors       42.709
# Doctorate       47.409
# HS-grad         40.596
# Masters         44.169
# Preschool       28.118
# Prof-school     47.484
# Some-college    38.862
# Name: hours_per_week, dtype: float64

# %% [markdown]
# ## Sorting
# * ### sort_index() to sort by index
# * ### sort_values() to sort by values

# %%
# groupby income and country and then sort by their mean age within each data block
df_grouped = df.groupby(['income','native_country']).mean().sort_values('age', ascending = True)
df_grouped

# Note: In this example, the groupby, mean, and sort functions are stringed together in one line
# in the next example, we will show a different syntax so that you could write them on separate
# lines to make the code a little easier to read
# Out:
#                                age      fnlwgt  education_num  capital_gain  \
# income native_country
#  <=50K  Taiwan              29.323  181981.290         12.548        71.032
#  >50K   Dominican-Republic  30.500  220226.000          9.000     49999.500
#         Hong                31.500  294478.833         13.833         0.000
#  <=50K  Holand-Netherlands  32.000   27882.000         10.000         0.000
#         Guatemala           32.262  266016.016          5.951       116.148
#         El-Salvador         32.649  264114.124          6.340       190.773
#  >50K   Thailand            32.667  199784.000         12.667         0.000
#  <=50K  Honduras            32.750  272571.000          8.167         0.000
#         Mexico              32.902  289038.116          5.959       135.538
#  >50K   Peru                33.500  314562.500         11.500         0.000
#  <=50K  Nicaragua           33.594  287987.906          8.656       212.312
#         Laos                33.938  209838.188          8.500       180.312
# ...                            ...         ...            ...           ...
#  >50K   Honduras            47.000   51835.000         15.000         0.000
#  <=50K  Hungary             47.000  182993.800         10.700       413.800
#         Cuba                47.286  243906.229          9.043       136.986
#  >50K   Ecuador             47.500  169428.750         10.500      2346.500
#         Haiti               48.000  206832.500          9.500         0.000
#         El-Salvador         50.111  149620.556         12.222      4708.111
#         Greece              50.250  121954.125         11.125      3741.250
#         Italy               50.360  185383.360         10.960      1253.040
#         Poland              50.583  179314.167         11.083      2743.083
#         Scotland            52.667  208306.667         10.667      1726.000
#         Columbia            53.500  283410.500         15.500         0.000
#         Hungary             57.333  172137.333         11.000      1726.000
#
#                             capital_loss  hours_per_week
# income native_country
#  <=50K  Taiwan                    51.677          33.774
#  >50K   Dominican-Republic         0.000          47.000
#         Hong                     329.500          45.000
#  <=50K  Holand-Netherlands      2205.000          40.000
#         Guatemala                 26.131          39.361
#         El-Salvador               34.000          36.031
#  >50K   Thailand                   0.000          58.333
#  <=50K  Honduras                   0.000          34.333
#         Mexico                    22.990          40.003
#  >50K   Peru                     924.000          40.000
#  <=50K  Nicaragua                 49.344          36.094
#         Laos                       0.000          40.375
# ...                                  ...             ...
#  >50K   Honduras                1902.000          60.000
#  <=50K  Hungary                  166.800          31.300
#         Cuba                      19.714          37.986
#  >50K   Ecuador                    0.000          48.750
#         Haiti                      0.000          42.750
#         El-Salvador                0.000          45.000
#         Greece                   539.625          50.625
#         Italy                     79.080          45.400
#         Poland                     0.000          39.000
#         Scotland                   0.000          46.667
#         Columbia                   0.000          50.000
#         Hungary                    0.000          50.000
#
# [82 rows x 6 columns]

# %%
# We want to group people by their income and country
# Then sort them by their income ASCE, and then sort by average age within that group DESC 
(df
 .groupby(['income','native_country'])
 .mean()
 .reset_index()
 .sort_values(['income','age'], ascending=[True,False])
)

# Note: In this example, we sort by the SAME column which we grouped by earlier 
# (eg. we first groupby 'income' and then sort by 'income')
# In this case, we must use .reset_index() to re-index the groupby objects, because the 'income' 
# column no longer exists after the groupby and hence cannot be sorted directly
# Out:
#     income       native_country     age      fnlwgt  education_num  \
# 5    <=50K                 Cuba  47.286  243906.229          9.043
# 18   <=50K              Hungary  47.000  182993.800         10.700
# 12   <=50K               Greece  44.667  151661.286          9.190
# 22   <=50K                Italy  44.375  179759.375          7.750
# 3    <=50K                China  41.800  175689.182         10.309
# 31   <=50K               Poland  41.250  185051.479          9.854
# 38   <=50K      Trinadad&Tobago  41.176  218778.941          8.412
# 2    <=50K               Canada  41.012  169279.585         10.244
# 32   <=50K             Portugal  40.333  153666.939          6.212
# 33   <=50K          Puerto-Rico  39.804  200316.010          8.108
# 4    <=50K             Columbia  39.228  223105.158          9.158
# 9    <=50K              England  38.967  185459.400         10.433
# ..     ...                  ...     ...         ...            ...
# 76    >50K               Taiwan  40.800  193354.550         14.450
# 67    >50K               Mexico  40.485  302417.000          9.394
# 52    >50K               France  40.167  172499.917         12.667
# 81    >50K           Yugoslavia  40.167  197059.167         10.333
# 72    >50K             Portugal  40.000  106998.250         10.750
# 55    >50K            Guatemala  35.667  247825.667          7.667
# 80    >50K              Vietnam  35.400  141648.400          9.600
# 68    >50K            Nicaragua  34.000  399953.500          9.500
# 69    >50K                 Peru  33.500  314562.500         11.500
# 77    >50K             Thailand  32.667  199784.000         12.667
# 58    >50K                 Hong  31.500  294478.833         13.833
# 48    >50K   Dominican-Republic  30.500  220226.000          9.000
#
#     capital_gain  capital_loss  hours_per_week
# 5        136.986        19.714          37.986
# 18       413.800       166.800          31.300
# 12       347.762       202.429          41.810
# 22       277.375         0.000          39.625
# 3        103.891        94.418          37.382
# 31       169.583        42.729          38.167
# 38         0.000       137.588          37.059
# 2        110.695       145.524          37.915
# 32       256.061         0.000          41.939
# 33        83.980        43.078          38.471
# 4        186.947        28.105          38.684
# 9        208.233        66.367          40.483
# ..           ...           ...             ...
# 76      5364.850       314.700          46.800
# 67      4256.394        57.182          46.576
# 52      1116.750         0.000          50.750
# 81       926.000         0.000          49.500
# 72         0.000         0.000          41.500
# 55      2562.667         0.000          36.667
# 80      5873.600         0.000          39.200
# 68         0.000       924.000          37.500
# 69         0.000       924.000          40.000
# 77         0.000         0.000          58.333
# 58         0.000       329.500          45.000
# 48     49999.500         0.000          47.000
#
# [82 rows x 8 columns]
